# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from matplotlib import pyplot
from tensorflow.keras.utils import plot_model

# %%
data=pd.read_csv("/home/jovyan/demo/IRIS.csv")
print(data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
x,y=data.values[:,:-1],data.values[:,-1]
x=x.astype('float32')
y=LabelEncoder().fit_transform(y)
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.33)
print(xtrain.shape,ytrain.shape,xtest.shape,ytest.shape)
nfeatures=xtrain.shape[1]
# Out:
# (100, 4) (100,) (50, 4) (50,)

# %%
#defining model
model=Sequential()
model.add(Dense(10,activation='relu',kernel_initializer='he_normal',input_shape=[nfeatures]))
# Out:
# WARNING:tensorflow:From /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.add(Dense(8,activation='relu',kernel_initializer='he_normal'))
model.add(Dense(3,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 10)                50
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 27
# ...
# Total params: 165
# Trainable params: 165
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(xtrain,ytrain,epochs=150,verbose=2)
# Out:
# Epoch 1/150
#  - 0s - loss: 10.7647 - acc: 0.3300
# Epoch 2/150
#  - 0s - loss: 10.7080 - acc: 0.3300
# Epoch 3/150
#  - 0s - loss: 10.5281 - acc: 0.3300
# Epoch 4/150
#  - 0s - loss: 10.2322 - acc: 0.3300
# Epoch 5/150
#  - 0s - loss: 9.8672 - acc: 0.3300
# Epoch 6/150
#  - 0s - loss: 9.3771 - acc: 0.3300
# Epoch 7/150
#  - 0s - loss: 8.8082 - acc: 0.3300
# Epoch 8/150
#  - 0s - loss: 8.1817 - acc: 0.3300
# Epoch 9/150
#  - 0s - loss: 7.5544 - acc: 0.3300
# Epoch 10/150
#  - 0s - loss: 6.9124 - acc: 0.3300
# Epoch 11/150
#  - 0s - loss: 6.3380 - acc: 0.3300
# Epoch 12/150
#  - 0s - loss: 5.7829 - acc: 0.3300
# Epoch 13/150
#  - 0s - loss: 5.2660 - acc: 0.3300
# Epoch 14/150
#  - 0s - loss: 4.8183 - acc: 0.3300
# Epoch 15/150
#  - 0s - loss: 4.3979 - acc: 0.3300
# Epoch 16/150
#  - 0s - loss: 4.0102 - acc: 0.3300
# Epoch 17/150
#  - 0s - loss: 3.6862 - acc: 0.3300
# Epoch 18/150
#  - 0s - loss: 3.3870 - acc: 0.3300
# Epoch 19/150
#  - 0s - loss: 3.1210 - acc: 0.3200
# Epoch 20/150
# ...

# %%
loss,acc=model.evaluate(xtest,ytest,verbose=2)
# Out:
#  - 0s - loss: 0.2622 - acc: 0.9600

# %%
print("test_accuracy is ",acc )
# Out:
# test_accuracy is  0.96
